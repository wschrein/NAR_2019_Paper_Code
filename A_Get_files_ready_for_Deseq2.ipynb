# %%
# import the files that you need
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from __future__ import division 
# %matplotlib inline

# %%
# import the feature counts results from DESEQ2
counts = pd.read_table("feature_counts_s2_all_bam.txt", index_col=0,
                       comment="#")
# Out:
# /home/wschrein/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# print summary.shape
print counts.shape
counts.head()
# Out:
# (46739, 11)
#                     Chr                Start                  End   Strand  \
# Geneid
# WBGene00197333        V                  180                  329        +
# WBGene00198386        V                  180                  329        -
# WBGene00015153  V;V;V;V  1691;2851;5538;6024  1782;3019;5966;6511  +;+;+;+
# WBGene00002061  V;V;V;V  6589;7158;7433;7651  7110;7393;7609;7822  -;-;-;-
# WBGene00255704        V                 8377                 8739        -
#
#                 Length  \
# Geneid
# WBGene00197333     150
# WBGene00198386     150
# WBGene00015153    1178
# WBGene00002061    1107
# WBGene00255704     363
#
#                 /home/wschrein/scratch/nuevo/att_1/Sample1Aligned.out.sam.sorted.bam  \
# Geneid
# WBGene00197333                                                  0
# WBGene00198386                                                  0
# WBGene00015153                                                  2
# ...

# %%
# drop the unnecessary information
counts.drop(['Chr', 'Start', 'End', 'Strand'], axis=1, inplace=True)
counts.head()
# Out:
#                 Length  \
# Geneid
# WBGene00197333     150
# WBGene00198386     150
# WBGene00015153    1178
# WBGene00002061    1107
# WBGene00255704     363
#
#                 /home/wschrein/scratch/nuevo/att_1/Sample1Aligned.out.sam.sorted.bam  \
# Geneid
# WBGene00197333                                                  0
# WBGene00198386                                                  0
# WBGene00015153                                                  2
# WBGene00002061                                               4640
# WBGene00255704                                                  5
#
#                 /home/wschrein/scratch/nuevo/att_1/Sample2Aligned.out.sam.sorted.bam  \
# Geneid
# WBGene00197333                                                  0
# WBGene00198386                                                  0
# WBGene00015153                                                  5
# WBGene00002061                                               5807
# ...

# %%
# rename to something a bit more palatable

counts = counts.rename(columns ={"/home/wschrein/scratch/nuevo/att_1/Sample1Aligned.out.sam.sorted.bam": "N2_CTR_1",
                       "/home/wschrein/scratch/nuevo/att_1/Sample2Aligned.out.sam.sorted.bam": "N2_CTR_3",
                       "/home/wschrein/scratch/nuevo/att_1/Sample3Aligned.out.sam.sorted.bam": "N2_CTR_4",
                       "/home/wschrein/scratch/nuevo/att_1/Sample4Aligned.out.sam.sorted.bam": "N2_HS_1",
                       "/home/wschrein/scratch/nuevo/att_1/Sample5Aligned.out.sam.sorted.bam": "N2_HS_3",
                       "/home/wschrein/scratch/nuevo/att_1/Sample6Aligned.out.sam.sorted.bam": "N2_HS_4"})
counts.head()
# Out:
#                 Length  N2_CTR_1  N2_CTR_3  N2_CTR_4  N2_HS_1  N2_HS_3  \
# Geneid
# WBGene00197333     150         0         0         0        0        0
# WBGene00198386     150         0         0         0        0        0
# WBGene00015153    1178         2         5         7      174       26
# WBGene00002061    1107      4640      5807      5218     1386     1238
# WBGene00255704     363         5         1         4       48       19
#
#                 N2_HS_4
# Geneid
# WBGene00197333        0
# WBGene00198386        0
# WBGene00015153       61
# WBGene00002061     1954
# WBGene00255704       37

# %%
# these will be the counts for deseq2

counts.to_csv('counts_for_deseq2.csv')

# %%
conditions = pd.DataFrame(index=counts.columns[1:])
conditions.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [N2_CTR_1, N2_CTR_3, N2_CTR_4, N2_HS_1, N2_HS_3]

# %%
features = ['CTR', 'CTR', 'CTR', 'HS', 'HS', 'HS']
conditions['condition'] = features

# %%
conditions.to_csv('conditions_for_deseq2.csv')
